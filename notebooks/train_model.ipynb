# %% [markdown]
# # Training

# %% [markdown]
# This notebook trains drafting models based on 17lands data

# %% [markdown]
# ### Steps
# First download data from 17lands:
# 1. Create a folder statistical-drafting/data/17lands/
# 2. Download draft data from [17lands](https://www.17lands.com/public_datasets) into the above folder
# 3. Download an updated statistical-drafting/data/cards.csv file from [17lands](https://www.17lands.com/public_datasets) to support new sets
# 4. Run the rest of this notebook to perform model training

# %%
# Install package
# %pip install .. -q

import os
import pandas as pd
import torch
from torch.utils.data import DataLoader, Dataset

import statisticaldrafting as sd

# Create data folder if it doesn't exist yet. 
# !mkdir -p ../data/17lands/
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Get all available sets for training. 
set_abbreviations, draft_modes = [], []
for fn in os.listdir("../data/17lands/"):
    if len(fn) > 20:
        sa, dm = fn.split(".")[1], fn.split(".")[2][:-5]
        set_abbreviations.append(sa)
        draft_modes.append(dm)

# %%
# Train models. 
for set_abbreviation, draft_mode in zip(["FDN"], ["Premier"]): # Single set. 
# for set_abbreviation, draft_mode in zip(set_abbreviations, draft_modes): # All models. 
        try:
                print(f"Starting training for {set_abbreviation}, {draft_mode}")
                sd.default_training_pipeline(set_abbreviation, draft_mode, overwrite_dataset=True)
        except:
                print(f"Error for: {set_abbreviation}, {draft_mode}")
# Out:
# Starting training for FDN, Premier
# Using input file ../data/17lands/draft_data_public.FDN.PremierDraft.csv.gz
# Completed initialization.
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Loaded 0 picks, t= 1.7 s
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Loaded 1000000 picks, t= 19.2 s
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Loaded 2000000 picks, t= 37.5 s
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Loaded 3000000 picks, t= 54.9 s
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Filtering by date
# Filtering by match winrate>=0.66 and n_games>=100
# Loaded all draft data.
# A total of 17609 picks in the training set.
# Saved training set to ../data/training_sets/FDN_Premier_train.pth
# Saved validation set to ../data/training_sets/FDN_Premier_val.pth
# Using existing cardname file, ../data/cards/FDN.csv
# Starting to train model. learning_rate=0.01
# Validation set pick accuracy = 18.0%
#
# Starting epoch 0
# Training loss: 5.53
#
# Starting epoch 1
# Training loss: 4.7998
#
# Starting epoch 2
# Training loss: 4.1193
# Validation set pick accuracy = 43.5%
# Saving model weights to ../data/models/FDN_Premier.pt
#
# Starting epoch 3
# Training loss: 3.5499
#
# Starting epoch 4
# Training loss: 3.1078
# Validation set pick accuracy = 45.6%
# Saving model weights to ../data/models/FDN_Premier.pt
#
# Starting epoch 5
# Training loss: 2.7694
#
# Starting epoch 6
# Training loss: 2.4618
# Validation set pick accuracy = 51.9%
# Saving model weights to ../data/models/FDN_Premier.pt
#
# Starting epoch 7
# Training loss: 2.2093
#
# Starting epoch 8
# Training loss: 1.9682
# Validation set pick accuracy = 56.2%
# Saving model weights to ../data/models/FDN_Premier.pt
#
# Starting epoch 9
# Training loss: 1.7632
#
# Starting epoch 10
# Training loss: 1.5678
# Validation set pick accuracy = 59.6%
# Saving model weights to ../data/models/FDN_Premier.pt
#
# Starting epoch 11
# Training loss: 1.395
#
# Starting epoch 12
# Training loss: 1.2288
# Validation set pick accuracy = 62.0%
# Saving model weights to ../data/models/FDN_Premier.pt
#
# Starting epoch 13
# Training loss: 1.1008
#
# Starting epoch 14
# Training loss: 0.9862
# Validation set pick accuracy = 62.7%
# Saving model weights to ../data/models/FDN_Premier.pt
#
# Starting epoch 15
# Training loss: 0.8855
#
# Starting epoch 16
# Training loss: 0.8128
# Validation set pick accuracy = 62.9%
# Saving model weights to ../data/models/FDN_Premier.pt
#
# Starting epoch 17
# Training loss: 0.7494
#
# Starting epoch 18
# Training loss: 0.7151
# Validation set pick accuracy = 63.0%
# Saving model weights to ../data/models/FDN_Premier.pt
#
# Starting epoch 19
# Training loss: 0.6688
#
# Starting epoch 20
# Training loss: 0.6362
# Validation set pick accuracy = 63.3%
# Saving model weights to ../data/models/FDN_Premier.pt
#
# Starting epoch 21
# Training loss: 0.5973
#
# Starting epoch 22
# Training loss: 0.5771
# Validation set pick accuracy = 63.6%
# Saving model weights to ../data/models/FDN_Premier.pt
#
# Starting epoch 23
# Training loss: 0.5538
#
# Starting epoch 24
# Training loss: 0.5355
# Validation set pick accuracy = 64.1%
# Saving model weights to ../data/models/FDN_Premier.pt
#
# Starting epoch 25
# Training loss: 0.5205
#
# Starting epoch 26
# Training loss: 0.5016
# Validation set pick accuracy = 64.0%
#
# Starting epoch 27
# Training loss: 0.4826
#
# Starting epoch 28
# Training loss: 0.4776
# Validation set pick accuracy = 64.0%
#
# Starting epoch 29
# Training loss: 0.4556
#
# Starting epoch 30
# Training loss: 0.446
# Validation set pick accuracy = 64.0%
#
# Starting epoch 31
# Training loss: 0.4301
#
# Starting epoch 32
# Training loss: 0.4166
# Validation set pick accuracy = 63.9%
#
# Starting epoch 33
# Training loss: 0.4136
#
# Starting epoch 34
# Training loss: 0.4007
# Validation set pick accuracy = 64.2%
# Saving model weights to ../data/models/FDN_Premier.pt
#
# Starting epoch 35
# Training loss: 0.395
#
# Starting epoch 36
# Training loss: 0.3859
# Validation set pick accuracy = 63.7%
#
# Starting epoch 37
# Training loss: 0.385
#
# Starting epoch 38
# Training loss: 0.3729
# Validation set pick accuracy = 63.0%
#
# Starting epoch 39
# Training loss: 0.3573
#
# Starting epoch 40
# Training loss: 0.3529
# Validation set pick accuracy = 63.5%
#
# Starting epoch 41
# Training loss: 0.3527
#
# Starting epoch 42
# Training loss: 0.3465
# Validation set pick accuracy = 62.9%
#
# Starting epoch 43
# Training loss: 0.3332
#
# Starting epoch 44
# Training loss: 0.3343
# Validation set pick accuracy = 62.8%
#
# Starting epoch 45
# Training loss: 0.3257
#
# Starting epoch 46
# Training loss: 0.3196
# Validation set pick accuracy = 63.2%
#
# Starting epoch 47
# Training loss: 0.3149
#
# Starting epoch 48
# Training loss: 0.3069
# Validation set pick accuracy = 62.7%
#
# Starting epoch 49
# Training loss: 0.3089
#
# Starting epoch 50
# Training loss: 0.3009
# Validation set pick accuracy = 62.8%
#
# Starting epoch 51
# Training loss: 0.2993
#
# Starting epoch 52
# Training loss: 0.292
# Validation set pick accuracy = 62.5%
#
# Starting epoch 53
# Training loss: 0.2975
#
# Starting epoch 54
# Training loss: 0.277
# Validation set pick accuracy = 62.2%
# Training complete. Time=31 seconds
