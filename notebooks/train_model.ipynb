# %% [markdown]
# # Training

# %% [markdown]
# This notebook trains drafting models based on 17lands data

# %% [markdown]
# ### Steps:
# 1. Download draft data from [17lands](https://www.17lands.com/public_datasets) into statistical-drafting/data/17lands/
# 2. Download an updated statistical-drafting/data/cards.csv file from [17lands](https://www.17lands.com/public_datasets) to support new sets
# 3. Run the rest of this notebook to perform model training

# %%
# Install package
# %pip install .. -q

import os
import pandas as pd
import torch
from torch.utils.data import DataLoader, Dataset

import statisticaldrafting as sd
# Out:
#   DEPRECATION: Building 'statisticaldrafting' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'statisticaldrafting'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# Note: you may need to restart the kernel to use updated packages.

# %%
# Get all available sets for training. 
set_abbreviations, draft_modes = [], []
for fn in os.listdir("../data/17lands/"):
    if len(fn) > 20:
        sa, dm = fn.split(".")[1], fn.split(".")[2][:-5]
        set_abbreviations.append(sa)
        draft_modes.append(dm)

# Train models. 
for set_abbreviation, draft_mode in zip(["FIN", "FIN"], ["Premier", "Trad"]): # Single set. 
# for set_abbreviation, draft_mode in zip(set_abbreviations, draft_modes): # All sets. 
        try:
                print(f"Starting training for {set_abbreviation}, {draft_mode}")
                sd.default_training_pipeline(set_abbreviation, draft_mode, overwrite_dataset=True)
        except:
                print(f"Error for: {set_abbreviation}, {draft_mode}")
# Out:
# Starting training for FIN, Premier
# Using input file ../data/17lands/draft_data_public.FIN.PremierDraft.csv.gz
# Completed initialization.
# Loaded 0 picks, t= 2.1 s
# Loaded 1000000 picks, t= 24.0 s
# Loaded 2000000 picks, t= 45.6 s
# Loaded 3000000 picks, t= 68.0 s
# Loaded 4000000 picks, t= 89.7 s
# Loaded all draft data.
# Created new cardname file for FIN, ../data/cards/FIN.csv
# A total of 170549 picks in the training set.
# Saved training set to ../data/training_sets/FIN_Premier_train.pth
# Saved validation set to ../data/training_sets/FIN_Premier_val.pth
# Starting to train model. learning_rate=0.03
# Validation set pick accuracy = 19.46%
#
# Starting epoch 0  lr=0.03
# Training loss: 3.397
#
# Starting epoch 1  lr=0.0282
# Training loss: 1.4039
#
# Starting epoch 2  lr=0.02651
# Training loss: 1.1579
# Validation set pick accuracy = 64.68%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 3  lr=0.02492
# Training loss: 1.0683
#
# Starting epoch 4  lr=0.02342
# Training loss: 1.0387
# Validation set pick accuracy = 66.61%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 5  lr=0.02202
# Training loss: 1.0175
#
# Starting epoch 6  lr=0.0207
# Training loss: 1.0109
# Validation set pick accuracy = 67.05%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 7  lr=0.01945
# Training loss: 0.9979
#
# Starting epoch 8  lr=0.01829
# Training loss: 0.985
# Validation set pick accuracy = 67.35%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 9  lr=0.01719
# Training loss: 0.9808
#
# Starting epoch 10  lr=0.01616
# Training loss: 0.9758
# Validation set pick accuracy = 67.28%
#
# Starting epoch 11  lr=0.01519
# Training loss: 0.9722
#
# Starting epoch 12  lr=0.01428
# Training loss: 0.9634
# Validation set pick accuracy = 67.67%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 13  lr=0.01342
# Training loss: 0.9656
#
# Starting epoch 14  lr=0.01262
# Training loss: 0.9567
# Validation set pick accuracy = 67.82%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 15  lr=0.01186
# Training loss: 0.9521
#
# Starting epoch 16  lr=0.01115
# Training loss: 0.9504
# Validation set pick accuracy = 68.18%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 17  lr=0.01048
# Training loss: 0.9436
#
# Starting epoch 18  lr=0.00985
# Training loss: 0.9388
# Validation set pick accuracy = 68.17%
#
# Starting epoch 19  lr=0.00926
# Training loss: 0.9335
#
# Starting epoch 20  lr=0.0087
# Training loss: 0.9386
# Validation set pick accuracy = 68.21%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 21  lr=0.00818
# Training loss: 0.9381
#
# Starting epoch 22  lr=0.00769
# Training loss: 0.9309
# Validation set pick accuracy = 68.22%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 23  lr=0.00723
# Training loss: 0.931
#
# Starting epoch 24  lr=0.0068
# Training loss: 0.931
# Validation set pick accuracy = 68.28%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 25  lr=0.00639
# Training loss: 0.9271
#
# Starting epoch 26  lr=0.006
# Training loss: 0.9187
# Validation set pick accuracy = 68.35%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 27  lr=0.00564
# Training loss: 0.9268
#
# Starting epoch 28  lr=0.00531
# Training loss: 0.9227
# Validation set pick accuracy = 68.47%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 29  lr=0.00499
# Training loss: 0.9164
#
# Starting epoch 30  lr=0.00469
# Training loss: 0.9148
# Validation set pick accuracy = 68.5%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 31  lr=0.00441
# Training loss: 0.915
#
# Starting epoch 32  lr=0.00414
# Training loss: 0.9088
# Validation set pick accuracy = 68.7%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 33  lr=0.00389
# Training loss: 0.9146
#
# Starting epoch 34  lr=0.00366
# Training loss: 0.9092
# Validation set pick accuracy = 68.58%
#
# Starting epoch 35  lr=0.00344
# Training loss: 0.9027
#
# Starting epoch 36  lr=0.00323
# Training loss: 0.9076
# Validation set pick accuracy = 68.71%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 37  lr=0.00304
# Training loss: 0.904
#
# Starting epoch 38  lr=0.00286
# Training loss: 0.909
# Validation set pick accuracy = 68.73%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 39  lr=0.00269
# Training loss: 0.9048
#
# Starting epoch 40  lr=0.00252
# Training loss: 0.9074
# Validation set pick accuracy = 68.84%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 41  lr=0.00237
# Training loss: 0.8978
#
# Starting epoch 42  lr=0.00223
# Training loss: 0.8972
# Validation set pick accuracy = 68.87%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 43  lr=0.0021
# Training loss: 0.8983
#
# Starting epoch 44  lr=0.00197
# Training loss: 0.8958
# Validation set pick accuracy = 68.85%
#
# Starting epoch 45  lr=0.00185
# Training loss: 0.8976
#
# Starting epoch 46  lr=0.00174
# Training loss: 0.8993
# Validation set pick accuracy = 68.77%
#
# Starting epoch 47  lr=0.00164
# Training loss: 0.8963
#
# Starting epoch 48  lr=0.00154
# Training loss: 0.8951
# Validation set pick accuracy = 68.81%
#
# Starting epoch 49  lr=0.00145
# Training loss: 0.8873
#
# Starting epoch 50  lr=0.00136
# Training loss: 0.8985
# Validation set pick accuracy = 68.96%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 51  lr=0.00128
# Training loss: 0.9002
#
# Starting epoch 52  lr=0.0012
# Training loss: 0.8918
# Validation set pick accuracy = 68.81%
#
# Starting epoch 53  lr=0.00113
# Training loss: 0.8895
#
# Starting epoch 54  lr=0.00106
# Training loss: 0.8904
# Validation set pick accuracy = 68.97%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 55  lr=0.001
# Training loss: 0.8931
#
# Starting epoch 56  lr=0.00094
# Training loss: 0.8875
# Validation set pick accuracy = 68.95%
#
# Starting epoch 57  lr=0.00088
# Training loss: 0.8923
#
# Starting epoch 58  lr=0.00083
# Training loss: 0.8853
# Validation set pick accuracy = 68.93%
#
# Starting epoch 59  lr=0.00078
# Training loss: 0.8838
#
# Starting epoch 60  lr=0.00073
# Training loss: 0.8855
# Validation set pick accuracy = 68.85%
#
# Starting epoch 61  lr=0.00069
# Training loss: 0.8916
#
# Starting epoch 62  lr=0.00065
# Training loss: 0.8899
# Validation set pick accuracy = 68.85%
#
# Starting epoch 63  lr=0.00061
# Training loss: 0.8892
#
# Starting epoch 64  lr=0.00057
# Training loss: 0.8883
# Validation set pick accuracy = 68.95%
#
# Starting epoch 65  lr=0.00054
# Training loss: 0.8881
#
# Starting epoch 66  lr=0.00051
# Training loss: 0.8792
# Validation set pick accuracy = 68.95%
#
# Starting epoch 67  lr=0.00047
# Training loss: 0.8831
#
# Starting epoch 68  lr=0.00045
# Training loss: 0.8864
# Validation set pick accuracy = 69.02%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 69  lr=0.00042
# Training loss: 0.8862
#
# Starting epoch 70  lr=0.00039
# Training loss: 0.8859
# Validation set pick accuracy = 69.0%
#
# Starting epoch 71  lr=0.00037
# Training loss: 0.8832
#
# Starting epoch 72  lr=0.00035
# Training loss: 0.8832
# Validation set pick accuracy = 69.02%
#
# Starting epoch 73  lr=0.00033
# Training loss: 0.8824
#
# Starting epoch 74  lr=0.00031
# Training loss: 0.8787
# Validation set pick accuracy = 68.98%
#
# Starting epoch 75  lr=0.00029
# Training loss: 0.8851
#
# Starting epoch 76  lr=0.00027
# Training loss: 0.8875
# Validation set pick accuracy = 68.99%
#
# Starting epoch 77  lr=0.00026
# Training loss: 0.8893
#
# Starting epoch 78  lr=0.00024
# Training loss: 0.8873
# Validation set pick accuracy = 69.04%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 79  lr=0.00023
# Training loss: 0.8839
#
# Starting epoch 80  lr=0.00021
# Training loss: 0.8799
# Validation set pick accuracy = 68.95%
#
# Starting epoch 81  lr=0.0002
# Training loss: 0.8906
#
# Starting epoch 82  lr=0.00019
# Training loss: 0.8814
# Validation set pick accuracy = 68.94%
#
# Starting epoch 83  lr=0.00018
# Training loss: 0.8833
#
# Starting epoch 84  lr=0.00017
# Training loss: 0.8869
# Validation set pick accuracy = 69.02%
#
# Starting epoch 85  lr=0.00016
# Training loss: 0.882
#
# Starting epoch 86  lr=0.00015
# Training loss: 0.8852
# Validation set pick accuracy = 69.04%
#
# Starting epoch 87  lr=0.00014
# Training loss: 0.8863
#
# Starting epoch 88  lr=0.00013
# Training loss: 0.8823
# Validation set pick accuracy = 69.09%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 89  lr=0.00012
# Training loss: 0.8868
#
# Starting epoch 90  lr=0.00011
# Training loss: 0.8866
# Validation set pick accuracy = 69.07%
#
# Starting epoch 91  lr=0.00011
# Training loss: 0.8776
#
# Starting epoch 92  lr=0.0001
# Training loss: 0.8859
# Validation set pick accuracy = 69.07%
#
# Starting epoch 93  lr=0.0001
# Training loss: 0.8858
#
# Starting epoch 94  lr=9e-05
# Training loss: 0.8866
# Validation set pick accuracy = 69.07%
#
# Starting epoch 95  lr=8e-05
# Training loss: 0.8833
#
# Starting epoch 96  lr=8e-05
# Training loss: 0.89
# Validation set pick accuracy = 69.1%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 97  lr=7e-05
# Training loss: 0.8855
#
# Starting epoch 98  lr=7e-05
# Training loss: 0.8877
# Validation set pick accuracy = 69.09%
#
# Starting epoch 99  lr=7e-05
# Training loss: 0.8859
#
# Starting epoch 100  lr=6e-05
# Training loss: 0.8827
# Validation set pick accuracy = 69.09%
#
# Starting epoch 101  lr=6e-05
# Training loss: 0.8848
#
# Starting epoch 102  lr=5e-05
# Training loss: 0.8884
# Validation set pick accuracy = 69.07%
#
# Starting epoch 103  lr=5e-05
# Training loss: 0.8864
#
# Starting epoch 104  lr=5e-05
# Training loss: 0.8844
# Validation set pick accuracy = 69.06%
#
# Starting epoch 105  lr=5e-05
# Training loss: 0.8827
#
# Starting epoch 106  lr=4e-05
# Training loss: 0.8882
# Validation set pick accuracy = 69.08%
#
# Starting epoch 107  lr=4e-05
# Training loss: 0.884
#
# Starting epoch 108  lr=4e-05
# Training loss: 0.8827
# Validation set pick accuracy = 69.07%
#
# Starting epoch 109  lr=4e-05
# Training loss: 0.8846
#
# Starting epoch 110  lr=3e-05
# Training loss: 0.8796
# Validation set pick accuracy = 69.07%
#
# Starting epoch 111  lr=3e-05
# Training loss: 0.8796
#
# Starting epoch 112  lr=3e-05
# Training loss: 0.8871
# Validation set pick accuracy = 69.03%
#
# Starting epoch 113  lr=3e-05
# Training loss: 0.8842
#
# Starting epoch 114  lr=3e-05
# Training loss: 0.8848
# Validation set pick accuracy = 69.08%
#
# Starting epoch 115  lr=2e-05
# Training loss: 0.8875
#
# Starting epoch 116  lr=2e-05
# Training loss: 0.8864
# Validation set pick accuracy = 69.04%
#
# Starting epoch 117  lr=2e-05
# Training loss: 0.8818
#
# Starting epoch 118  lr=2e-05
# Training loss: 0.8843
# Validation set pick accuracy = 69.11%
# Saving model weights to ../data/models/FIN_Premier.pt
#
# Starting epoch 119  lr=2e-05
# Training loss: 0.886
#
# Starting epoch 120  lr=2e-05
# Training loss: 0.8815
# Validation set pick accuracy = 69.07%
#
# Starting epoch 121  lr=2e-05
# Training loss: 0.8812
#
# Starting epoch 122  lr=2e-05
# Training loss: 0.8813
# Validation set pick accuracy = 69.07%
#
# Starting epoch 123  lr=1e-05
# Training loss: 0.8854
#
# Starting epoch 124  lr=1e-05
# Training loss: 0.8814
# Validation set pick accuracy = 69.05%
#
# Starting epoch 125  lr=1e-05
# Training loss: 0.8852
#
# Starting epoch 126  lr=1e-05
# Training loss: 0.8822
# Validation set pick accuracy = 69.09%
#
# Starting epoch 127  lr=1e-05
# Training loss: 0.8814
#
# Starting epoch 128  lr=1e-05
# Training loss: 0.8813
# Validation set pick accuracy = 69.08%
#
# Starting epoch 129  lr=1e-05
# Training loss: 0.8782
#
# Starting epoch 130  lr=1e-05
# Training loss: 0.8875
# Validation set pick accuracy = 69.07%
#
# Starting epoch 131  lr=1e-05
# Training loss: 0.8776
#
# Starting epoch 132  lr=1e-05
# Training loss: 0.8813
# Validation set pick accuracy = 69.07%
#
# Starting epoch 133  lr=1e-05
# Training loss: 0.8817
#
# Starting epoch 134  lr=1e-05
# Training loss: 0.8871
# Validation set pick accuracy = 69.07%
#
# Starting epoch 135  lr=1e-05
# Training loss: 0.8837
#
# Starting epoch 136  lr=1e-05
# Training loss: 0.8847
# Validation set pick accuracy = 69.1%
#
# Starting epoch 137  lr=1e-05
# Training loss: 0.8804
#
# Starting epoch 138  lr=1e-05
# Training loss: 0.883
# Validation set pick accuracy = 69.08%
#
# Starting epoch 139  lr=1e-05
# Training loss: 0.8887
#
# Starting epoch 140  lr=1e-05
# Training loss: 0.8814
# Validation set pick accuracy = 69.07%
#
# Starting epoch 141  lr=0.0
# Training loss: 0.8837
#
# Starting epoch 142  lr=0.0
# Training loss: 0.8813
# Validation set pick accuracy = 69.05%
#
# Starting epoch 143  lr=0.0
# Training loss: 0.883
#
# Starting epoch 144  lr=0.0
# Training loss: 0.8781
# Validation set pick accuracy = 69.07%
#
# Starting epoch 145  lr=0.0
# Training loss: 0.8829
#
# Starting epoch 146  lr=0.0
# Training loss: 0.884
# Validation set pick accuracy = 69.09%
#
# Starting epoch 147  lr=0.0
# Training loss: 0.8891
#
# Starting epoch 148  lr=0.0
# Training loss: 0.8769
# Validation set pick accuracy = 69.03%
#
# Starting epoch 149  lr=0.0
# Training loss: 0.8792
#
# Starting epoch 150  lr=0.0
# Training loss: 0.8833
# Validation set pick accuracy = 69.06%
#
# Starting epoch 151  lr=0.0
# Training loss: 0.8857
#
# Starting epoch 152  lr=0.0
# Training loss: 0.8846
# Validation set pick accuracy = 69.04%
#
# Starting epoch 153  lr=0.0
# Training loss: 0.8842
#
# Starting epoch 154  lr=0.0
# Training loss: 0.8854
# Validation set pick accuracy = 69.07%
#
# Starting epoch 155  lr=0.0
# Training loss: 0.8846
#
# Starting epoch 156  lr=0.0
# Training loss: 0.884
# Validation set pick accuracy = 69.06%
#
# Starting epoch 157  lr=0.0
# Training loss: 0.8838
#
# Starting epoch 158  lr=0.0
# Training loss: 0.8838
# Validation set pick accuracy = 69.05%
# Training complete for ../data/models/FIN_Premier.pt. Best performance=69.11% Time=977 seconds
#
# Starting training for FIN, Trad
# Using input file ../data/17lands/draft_data_public.FIN.TradDraft.csv.gz
# Completed initialization.
# Loaded 0 picks, t= 2.0 s
# Loaded all draft data.
# Using existing cardname file, ../data/cards/FIN.csv
# A total of 119330 picks in the training set.
# Saved training set to ../data/training_sets/FIN_Trad_train.pth
# Saved validation set to ../data/training_sets/FIN_Trad_val.pth
# Starting to train model. learning_rate=0.03
# Validation set pick accuracy = 18.18%
#
# Starting epoch 0  lr=0.03
# Training loss: 4.2644
#
# Starting epoch 1  lr=0.0282
# Training loss: 1.5806
#
# Starting epoch 2  lr=0.02651
# Training loss: 1.253
# Validation set pick accuracy = 63.07%
# Saving model weights to ../data/models/FIN_Trad.pt
#
# Starting epoch 3  lr=0.02492
# Training loss: 1.1242
#
# Starting epoch 4  lr=0.02342
# Training loss: 1.0648
# Validation set pick accuracy = 64.81%
# Saving model weights to ../data/models/FIN_Trad.pt
#
# Starting epoch 5  lr=0.02202
# Training loss: 1.0307
#
# Starting epoch 6  lr=0.0207
# Training loss: 1.0102
# Validation set pick accuracy = 65.97%
# Saving model weights to ../data/models/FIN_Trad.pt
#
# Starting epoch 7  lr=0.01945
# Training loss: 0.9937
#
# Starting epoch 8  lr=0.01829
# Training loss: 0.9822
# Validation set pick accuracy = 66.09%
# Saving model weights to ../data/models/FIN_Trad.pt
#
# Starting epoch 9  lr=0.01719
# Training loss: 0.9785
#
# Starting epoch 10  lr=0.01616
# Training loss: 0.9686
# Validation set pick accuracy = 66.54%
# Saving model weights to ../data/models/FIN_Trad.pt
#
# Starting epoch 11  lr=0.01519
# Training loss: 0.9612
#
# Starting epoch 12  lr=0.01428
# Training loss: 0.9578
# Validation set pick accuracy = 66.87%
# Saving model weights to ../data/models/FIN_Trad.pt
#
# Starting epoch 13  lr=0.01342
# Training loss: 0.951
#
# Starting epoch 14  lr=0.01262
# Training loss: 0.95
# Validation set pick accuracy = 66.95%
# Saving model weights to ../data/models/FIN_Trad.pt
#
# Starting epoch 15  lr=0.01186
# Training loss: 0.9434
#
# Starting epoch 16  lr=0.01115
# Training loss: 0.9382
# Validation set pick accuracy = 66.86%
#
# Starting epoch 17  lr=0.01048
# Training loss: 0.9355
#
# Starting epoch 18  lr=0.00985
# Training loss: 0.9308
# Validation set pick accuracy = 67.13%
# Saving model weights to ../data/models/FIN_Trad.pt
#
# Starting epoch 19  lr=0.00926
# Training loss: 0.929
#
# Starting epoch 20  lr=0.0087
# Training loss: 0.9192
# Validation set pick accuracy = 67.08%
#
# Starting epoch 21  lr=0.00818
# Training loss: 0.9229
#
# Starting epoch 22  lr=0.00769
# Training loss: 0.917
# Validation set pick accuracy = 67.31%
# Saving model weights to ../data/models/FIN_Trad.pt
#
# Starting epoch 23  lr=0.00723
# Training loss: 0.9165
#
# Starting epoch 24  lr=0.0068
# Training loss: 0.9151
# Validation set pick accuracy = 67.19%
#
# Starting epoch 25  lr=0.00639
# Training loss: 0.9088
#
# Starting epoch 26  lr=0.006
# Training loss: 0.9102
# Validation set pick accuracy = 67.57%
# Saving model weights to ../data/models/FIN_Trad.pt
#
# Starting epoch 27  lr=0.00564
# Training loss: 0.9057
#
# Starting epoch 28  lr=0.00531
# Training loss: 0.9052
# Validation set pick accuracy = 67.44%
#
# Starting epoch 29  lr=0.00499
# Training loss: 0.9022
#
# Starting epoch 30  lr=0.00469
# Training loss: 0.8989
# Validation set pick accuracy = 67.5%
#
# Starting epoch 31  lr=0.00441
# Training loss: 0.8954
#
# Starting epoch 32  lr=0.00414
# Training loss: 0.8975
# Validation set pick accuracy = 67.6%
# Saving model weights to ../data/models/FIN_Trad.pt
#
# Starting epoch 33  lr=0.00389
# Training loss: 0.8954
#
# Starting epoch 34  lr=0.00366
# Training loss: 0.8918
# Validation set pick accuracy = 67.49%
#
# Starting epoch 35  lr=0.00344
# Training loss: 0.8912
#
# Starting epoch 36  lr=0.00323
# Training loss: 0.8908
# Validation set pick accuracy = 67.61%
# Saving model weights to ../data/models/FIN_Trad.pt
#
# Starting epoch 37  lr=0.00304
# Training loss: 0.8854
#
# Starting epoch 38  lr=0.00286
# Training loss: 0.8885
# Validation set pick accuracy = 67.54%
#
# Starting epoch 39  lr=0.00269
# Training loss: 0.8864
#
# Starting epoch 40  lr=0.00252
# Training loss: 0.8856
# Validation set pick accuracy = 67.48%
#
# Starting epoch 41  lr=0.00237
# Training loss: 0.883
#
# Starting epoch 42  lr=0.00223
# Training loss: 0.8822
# Validation set pick accuracy = 67.75%
# Saving model weights to ../data/models/FIN_Trad.pt
#
# Starting epoch 43  lr=0.0021
# Training loss: 0.8825
#
# Starting epoch 44  lr=0.00197
# Training loss: 0.8805
# Validation set pick accuracy = 67.65%
#
# Starting epoch 45  lr=0.00185
# Training loss: 0.8774
#
# Starting epoch 46  lr=0.00174
# Training loss: 0.8789
# Validation set pick accuracy = 67.61%
#
# Starting epoch 47  lr=0.00164
# Training loss: 0.8796
#
# Starting epoch 48  lr=0.00154
# Training loss: 0.8763
# Validation set pick accuracy = 67.61%
#
# Starting epoch 49  lr=0.00145
# Training loss: 0.877
#
# Starting epoch 50  lr=0.00136
# Training loss: 0.8759
# Validation set pick accuracy = 67.52%
#
# Starting epoch 51  lr=0.00128
# Training loss: 0.8771
#
# Starting epoch 52  lr=0.0012
# Training loss: 0.8745
# Validation set pick accuracy = 67.66%
#
# Starting epoch 53  lr=0.00113
# Training loss: 0.8736
#
# Starting epoch 54  lr=0.00106
# Training loss: 0.875
# Validation set pick accuracy = 67.59%
#
# Starting epoch 55  lr=0.001
# Training loss: 0.8737
#
# Starting epoch 56  lr=0.00094
# Training loss: 0.8731
# Validation set pick accuracy = 67.69%
#
# Starting epoch 57  lr=0.00088
# Training loss: 0.8739
#
# Starting epoch 58  lr=0.00083
# Training loss: 0.8721
# Validation set pick accuracy = 67.73%
#
# Starting epoch 59  lr=0.00078
# Training loss: 0.8718
#
# Starting epoch 60  lr=0.00073
# Training loss: 0.8719
# Validation set pick accuracy = 67.68%
#
# Starting epoch 61  lr=0.00069
# Training loss: 0.869
#
# Starting epoch 62  lr=0.00065
# Training loss: 0.8732
# Validation set pick accuracy = 67.68%
#
# Starting epoch 63  lr=0.00061
# Training loss: 0.8688
#
# Starting epoch 64  lr=0.00057
# Training loss: 0.8721
# Validation set pick accuracy = 67.71%
#
# Starting epoch 65  lr=0.00054
# Training loss: 0.8699
#
# Starting epoch 66  lr=0.00051
# Training loss: 0.8683
# Validation set pick accuracy = 67.65%
#
# Starting epoch 67  lr=0.00047
# Training loss: 0.8659
#
# Starting epoch 68  lr=0.00045
# Training loss: 0.8684
# Validation set pick accuracy = 67.71%
#
# Starting epoch 69  lr=0.00042
# Training loss: 0.8683
#
# Starting epoch 70  lr=0.00039
# Training loss: 0.869
# Validation set pick accuracy = 67.65%
#
# Starting epoch 71  lr=0.00037
# Training loss: 0.8684
#
# Starting epoch 72  lr=0.00035
# Training loss: 0.8687
# Validation set pick accuracy = 67.75%
#
# Starting epoch 73  lr=0.00033
# Training loss: 0.8707
#
# Starting epoch 74  lr=0.00031
# Training loss: 0.8674
# Validation set pick accuracy = 67.7%
#
# Starting epoch 75  lr=0.00029
# Training loss: 0.8674
#
# Starting epoch 76  lr=0.00027
# Training loss: 0.8657
# Validation set pick accuracy = 67.71%
#
# Starting epoch 77  lr=0.00026
# Training loss: 0.8684
#
# Starting epoch 78  lr=0.00024
# Training loss: 0.8674
# Validation set pick accuracy = 67.72%
#
# Starting epoch 79  lr=0.00023
# Training loss: 0.8658
#
# Starting epoch 80  lr=0.00021
# Training loss: 0.8699
# Validation set pick accuracy = 67.71%
#
# Starting epoch 81  lr=0.0002
# Training loss: 0.8667
#
# Starting epoch 82  lr=0.00019
# Training loss: 0.8677
# Validation set pick accuracy = 67.72%
# Training complete for ../data/models/FIN_Trad.pt. Best performance=67.75% Time=351 seconds
