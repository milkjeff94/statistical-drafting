# %% [markdown]
# # Training

# %% [markdown]
# This notebook trains drafting models based on 17lands data

# %% [markdown]
# ### Prerequisites
# First download data from 17lands:
# 1. Create a folder statistical-drafting/data/17lands/
# 2. Download draft data from [17lands](https://www.17lands.com/public_datasets) into the above folder
# 3. Download an updated statistical-drafting/data/cards.csv file from [17lands](https://www.17lands.com/public_datasets) to support new sets
# 4. Run the rest of this notebook to perform model training

# %%
# !mkdir -p ../data/17lands/

# %%
# If import fails, run the following command in project root. 
# pip install -e .
# Reinstall package. 
# %pip install .. -q

import os
import pandas as pd
import torch
from torch.utils.data import DataLoader, Dataset

import statisticaldrafting as sd
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# List all available sets for training. 
set_abbreviations, draft_modes = [], []
for fn in os.listdir("../data/17lands/"):
    if len(fn) > 20:
        sa, dm = fn.split(".")[1], fn.split(".")[2][:-5]
        set_abbreviations.append(sa)
        draft_modes.append(dm)
        # print(sa, dm) # Print sets here.

# %%
# Train all models.
for set_abbreviation, draft_mode in zip(set_abbreviations, draft_modes):
        try:
                print(f"Starting training for {set_abbreviation}, {draft_mode}")
                sd.default_training_pipeline(set_abbreviation, draft_mode, overwrite_dataset=True)
        except:
                print(f"Error for: {set_abbreviation}, {draft_mode}")
# Out:
# Starting training for STX, Trad
# Using input file ../data/17lands/draft_data_public.STX.TradDraft.csv.gz
# Completed initialization.
# Filtering by match wins >= 3
# Loaded 0 picks, t= 2.1 s
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Loaded all draft data.
# Saved training set to ../data/training_sets/STX_Trad_train.pth
# Saved validation set to ../data/training_sets/STX_Trad_val.pth
# Using existing cardname file, ../data/cards/STX.csv
# Starting to train model
# Validation set pick accuracy = 19.5%
#
# Starting epoch 0
# Training loss: 4.6263
#
# Starting epoch 1
# Training loss: 3.1535
#
# Starting epoch 2
# Training loss: 2.5951
# Validation set pick accuracy = 57.5%
# Saving model weights to ../data/models/STX_Trad.pt
#
# Starting epoch 3
# Training loss: 2.0446
#
# Starting epoch 4
# Training loss: 1.5638
# Validation set pick accuracy = 63.7%
# Saving model weights to ../data/models/STX_Trad.pt
#
# Starting epoch 5
# Training loss: 1.2564
#
# Starting epoch 6
# Training loss: 1.094
# Validation set pick accuracy = 65.5%
# Saving model weights to ../data/models/STX_Trad.pt
#
# Starting epoch 7
# Training loss: 1.004
#
# Starting epoch 8
# Training loss: 0.9537
# Validation set pick accuracy = 66.4%
# Saving model weights to ../data/models/STX_Trad.pt
#
# Starting epoch 9
# Training loss: 0.9187
#
# Starting epoch 10
# Training loss: 0.8938
# Validation set pick accuracy = 66.8%
# Saving model weights to ../data/models/STX_Trad.pt
#
# Starting epoch 11
# Training loss: 0.877
#
# Starting epoch 12
# Training loss: 0.8633
# Validation set pick accuracy = 67.0%
# Saving model weights to ../data/models/STX_Trad.pt
#
# Starting epoch 13
# Training loss: 0.8505
#
# Starting epoch 14
# Training loss: 0.8397
# Validation set pick accuracy = 67.2%
# Saving model weights to ../data/models/STX_Trad.pt
#
# Starting epoch 15
# Training loss: 0.8319
#
# Starting epoch 16
# Training loss: 0.8254
# Validation set pick accuracy = 67.2%
# Saving model weights to ../data/models/STX_Trad.pt
#
# Starting epoch 17
# Training loss: 0.819
#
# Starting epoch 18
# Training loss: 0.8124
# Validation set pick accuracy = 67.2%
# Saving model weights to ../data/models/STX_Trad.pt
#
# Starting epoch 19
# Training loss: 0.8068
#
# Starting epoch 20
# Training loss: 0.801
# Validation set pick accuracy = 67.4%
# Saving model weights to ../data/models/STX_Trad.pt
#
# Starting epoch 21
# Training loss: 0.794
#
# Starting epoch 22
# Training loss: 0.7894
# Validation set pick accuracy = 67.6%
# Saving model weights to ../data/models/STX_Trad.pt
#
# Starting epoch 23
# Training loss: 0.7837
#
# Starting epoch 24
# Training loss: 0.7785
# Validation set pick accuracy = 67.5%
# Training completed.
# Starting training for NEO, Premier
# Using input file ../data/17lands/draft_data_public.NEO.PremierDraft.csv.gz
# Completed initialization.
# Filtering by match wins >= 7
# Loaded 0 picks, t= 1.7 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 1000000 picks, t= 18.2 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 2000000 picks, t= 34.2 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 3000000 picks, t= 50.1 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 4000000 picks, t= 66.2 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded all draft data.
# Saved training set to ../data/training_sets/NEO_Premier_train.pth
# Saved validation set to ../data/training_sets/NEO_Premier_val.pth
# Using existing cardname file, ../data/cards/NEO.csv
# Starting to train model
# Validation set pick accuracy = 18.9%
#
# Starting epoch 0
# Training loss: 3.8018
#
# Starting epoch 1
# Training loss: 1.7815
#
# Starting epoch 2
# Training loss: 1.0738
# Validation set pick accuracy = 66.2%
# Saving model weights to ../data/models/NEO_Premier.pt
#
# Starting epoch 3
# Training loss: 0.9478
#
# Starting epoch 4
# Training loss: 0.9098
# Validation set pick accuracy = 66.9%
# Saving model weights to ../data/models/NEO_Premier.pt
#
# Starting epoch 5
# Training loss: 0.8915
#
# Starting epoch 6
# Training loss: 0.8794
# Validation set pick accuracy = 67.2%
# Saving model weights to ../data/models/NEO_Premier.pt
#
# Starting epoch 7
# Training loss: 0.8699
#
# Starting epoch 8
# Training loss: 0.8639
# Validation set pick accuracy = 67.2%
# Saving model weights to ../data/models/NEO_Premier.pt
#
# Starting epoch 9
# Training loss: 0.859
#
# Starting epoch 10
# Training loss: 0.8547
# Validation set pick accuracy = 67.4%
# Saving model weights to ../data/models/NEO_Premier.pt
#
# Starting epoch 11
# Training loss: 0.8513
#
# Starting epoch 12
# Training loss: 0.8467
# Validation set pick accuracy = 67.3%
#
# Starting epoch 13
# Training loss: 0.8437
#
# Starting epoch 14
# Training loss: 0.8414
# Validation set pick accuracy = 67.5%
# Saving model weights to ../data/models/NEO_Premier.pt
#
# Starting epoch 15
# Training loss: 0.8391
#
# Starting epoch 16
# Training loss: 0.8358
# Validation set pick accuracy = 67.5%
#
# Starting epoch 17
# Training loss: 0.8327
#
# Starting epoch 18
# Training loss: 0.8312
# Validation set pick accuracy = 67.4%
#
# Starting epoch 19
# Training loss: 0.8283
#
# Starting epoch 20
# Training loss: 0.8271
# Validation set pick accuracy = 67.4%
#
# Starting epoch 21
# Training loss: 0.8238
#
# Starting epoch 22
# Training loss: 0.8228
# Validation set pick accuracy = 67.5%
#
# Starting epoch 23
# Training loss: 0.8204
#
# Starting epoch 24
# Training loss: 0.8183
# Validation set pick accuracy = 67.5%
# Saving model weights to ../data/models/NEO_Premier.pt
# Training completed.
# Starting training for SNC, Trad
# Using input file ../data/17lands/draft_data_public.SNC.TradDraft.csv.gz
# Completed initialization.
# Filtering by match wins >= 3
# Loaded 0 picks, t= 1.5 s
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Loaded all draft data.
# Saved training set to ../data/training_sets/SNC_Trad_train.pth
# Saved validation set to ../data/training_sets/SNC_Trad_val.pth
# Using existing cardname file, ../data/cards/SNC.csv
# Starting to train model
# Validation set pick accuracy = 19.5%
#
# Starting epoch 0
# Training loss: 5.0063
#
# Starting epoch 1
# Training loss: 3.7683
#
# Starting epoch 2
# Training loss: 3.1254
# Validation set pick accuracy = 50.9%
# Saving model weights to ../data/models/SNC_Trad.pt
#
# Starting epoch 3
# Training loss: 2.7026
#
# Starting epoch 4
# Training loss: 2.353
# Validation set pick accuracy = 58.3%
# Saving model weights to ../data/models/SNC_Trad.pt
#
# Starting epoch 5
# Training loss: 2.0293
#
# Starting epoch 6
# Training loss: 1.7353
# Validation set pick accuracy = 62.7%
# Saving model weights to ../data/models/SNC_Trad.pt
#
# Starting epoch 7
# Training loss: 1.4803
#
# Starting epoch 8
# Training loss: 1.3016
# Validation set pick accuracy = 65.5%
# Saving model weights to ../data/models/SNC_Trad.pt
#
# Starting epoch 9
# Training loss: 1.1671
#
# Starting epoch 10
# Training loss: 1.0771
# Validation set pick accuracy = 66.5%
# Saving model weights to ../data/models/SNC_Trad.pt
#
# Starting epoch 11
# Training loss: 1.0115
#
# Starting epoch 12
# Training loss: 0.9663
# Validation set pick accuracy = 66.9%
# Saving model weights to ../data/models/SNC_Trad.pt
#
# Starting epoch 13
# Training loss: 0.9329
#
# Starting epoch 14
# Training loss: 0.9026
# Validation set pick accuracy = 67.3%
# Saving model weights to ../data/models/SNC_Trad.pt
#
# Starting epoch 15
# Training loss: 0.8848
#
# Starting epoch 16
# Training loss: 0.8641
# Validation set pick accuracy = 67.4%
# Saving model weights to ../data/models/SNC_Trad.pt
#
# Starting epoch 17
# Training loss: 0.8515
#
# Starting epoch 18
# Training loss: 0.8393
# Validation set pick accuracy = 67.6%
# Saving model weights to ../data/models/SNC_Trad.pt
#
# Starting epoch 19
# Training loss: 0.8261
#
# Starting epoch 20
# Training loss: 0.8171
# Validation set pick accuracy = 67.8%
# Saving model weights to ../data/models/SNC_Trad.pt
#
# Starting epoch 21
# Training loss: 0.8081
#
# Starting epoch 22
# Training loss: 0.8001
# Validation set pick accuracy = 67.7%
#
# Starting epoch 23
# Training loss: 0.7925
#
# Starting epoch 24
# Training loss: 0.7862
# Validation set pick accuracy = 67.8%
# Saving model weights to ../data/models/SNC_Trad.pt
# Training completed.
# Starting training for MID, Premier
# Using input file ../data/17lands/draft_data_public.MID.PremierDraft.csv.gz
# Completed initialization.
# Filtering by match wins >= 7
# Loaded 0 picks, t= 1.7 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 1000000 picks, t= 17.0 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 2000000 picks, t= 32.7 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 3000000 picks, t= 47.8 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded all draft data.
# Saved training set to ../data/training_sets/MID_Premier_train.pth
# Saved validation set to ../data/training_sets/MID_Premier_val.pth
# Using existing cardname file, ../data/cards/MID.csv
# Starting to train model
# Validation set pick accuracy = 18.8%
#
# Starting epoch 0
# Training loss: 3.6757
#
# Starting epoch 1
# Training loss: 1.7466
#
# Starting epoch 2
# Training loss: 1.0363
# Validation set pick accuracy = 68.7%
# Saving model weights to ../data/models/MID_Premier.pt
#
# Starting epoch 3
# Training loss: 0.8931
#
# Starting epoch 4
# Training loss: 0.8517
# Validation set pick accuracy = 69.6%
# Saving model weights to ../data/models/MID_Premier.pt
#
# Starting epoch 5
# Training loss: 0.8321
#
# Starting epoch 6
# Training loss: 0.8202
# Validation set pick accuracy = 69.9%
# Saving model weights to ../data/models/MID_Premier.pt
#
# Starting epoch 7
# Training loss: 0.8113
#
# Starting epoch 8
# Training loss: 0.8053
# Validation set pick accuracy = 69.9%
# Saving model weights to ../data/models/MID_Premier.pt
#
# Starting epoch 9
# Training loss: 0.801
#
# Starting epoch 10
# Training loss: 0.7953
# Validation set pick accuracy = 70.1%
# Saving model weights to ../data/models/MID_Premier.pt
#
# Starting epoch 11
# Training loss: 0.7926
#
# Starting epoch 12
# Training loss: 0.7886
# Validation set pick accuracy = 70.1%
# Saving model weights to ../data/models/MID_Premier.pt
#
# Starting epoch 13
# Training loss: 0.7855
#
# Starting epoch 14
# Training loss: 0.7823
# Validation set pick accuracy = 70.2%
# Saving model weights to ../data/models/MID_Premier.pt
#
# Starting epoch 15
# Training loss: 0.7808
#
# Starting epoch 16
# Training loss: 0.7778
# Validation set pick accuracy = 70.1%
#
# Starting epoch 17
# Training loss: 0.7754
#
# Starting epoch 18
# Training loss: 0.7726
# Validation set pick accuracy = 70.2%
#
# Starting epoch 19
# Training loss: 0.7706
#
# Starting epoch 20
# Training loss: 0.7682
# Validation set pick accuracy = 70.2%
#
# Starting epoch 21
# Training loss: 0.7658
#
# Starting epoch 22
# Training loss: 0.764
# Validation set pick accuracy = 70.1%
#
# Starting epoch 23
# Training loss: 0.7631
#
# Starting epoch 24
# Training loss: 0.7613
# Validation set pick accuracy = 70.2%
# Training completed.
# Starting training for LTR, Trad
# Using input file ../data/17lands/draft_data_public.LTR.TradDraft.csv.gz
# Completed initialization.
# Filtering by match wins >= 3
# Loaded 0 picks, t= 1.6 s
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Loaded all draft data.
# Saved training set to ../data/training_sets/LTR_Trad_train.pth
# Saved validation set to ../data/training_sets/LTR_Trad_val.pth
# Using existing cardname file, ../data/cards/LTR.csv
# Starting to train model
# Validation set pick accuracy = 16.2%
#
# Starting epoch 0
# Training loss: 4.8446
#
# Starting epoch 1
# Training loss: 3.535
#
# Starting epoch 2
# Training loss: 2.7572
# Validation set pick accuracy = 57.3%
# Saving model weights to ../data/models/LTR_Trad.pt
#
# Starting epoch 3
# Training loss: 2.175
#
# Starting epoch 4
# Training loss: 1.6746
# Validation set pick accuracy = 65.0%
# Saving model weights to ../data/models/LTR_Trad.pt
#
# Starting epoch 5
# Training loss: 1.3111
#
# Starting epoch 6
# Training loss: 1.1111
# Validation set pick accuracy = 67.7%
# Saving model weights to ../data/models/LTR_Trad.pt
#
# Starting epoch 7
# Training loss: 0.9986
#
# Starting epoch 8
# Training loss: 0.9375
# Validation set pick accuracy = 68.8%
# Saving model weights to ../data/models/LTR_Trad.pt
#
# Starting epoch 9
# Training loss: 0.8992
#
# Starting epoch 10
# Training loss: 0.8721
# Validation set pick accuracy = 68.9%
# Saving model weights to ../data/models/LTR_Trad.pt
#
# Starting epoch 11
# Training loss: 0.8516
#
# Starting epoch 12
# Training loss: 0.8411
# Validation set pick accuracy = 69.0%
# Saving model weights to ../data/models/LTR_Trad.pt
#
# Starting epoch 13
# Training loss: 0.8269
#
# Starting epoch 14
# Training loss: 0.818
# Validation set pick accuracy = 69.1%
# Saving model weights to ../data/models/LTR_Trad.pt
#
# Starting epoch 15
# Training loss: 0.8069
#
# Starting epoch 16
# Training loss: 0.8023
# Validation set pick accuracy = 69.3%
# Saving model weights to ../data/models/LTR_Trad.pt
#
# Starting epoch 17
# Training loss: 0.7961
#
# Starting epoch 18
# Training loss: 0.789
# Validation set pick accuracy = 69.1%
#
# Starting epoch 19
# Training loss: 0.7825
#
# Starting epoch 20
# Training loss: 0.7763
# Validation set pick accuracy = 69.3%
# Saving model weights to ../data/models/LTR_Trad.pt
#
# Starting epoch 21
# Training loss: 0.7711
#
# Starting epoch 22
# Training loss: 0.767
# Validation set pick accuracy = 69.2%
#
# Starting epoch 23
# Training loss: 0.7634
#
# Starting epoch 24
# Training loss: 0.7582
# Validation set pick accuracy = 69.2%
# Training completed.
# Starting training for HBG, Trad
# Using input file ../data/17lands/draft_data_public.HBG.TradDraft.csv.gz
# Completed initialization.
# Filtering by match wins >= 3
# Loaded 0 picks, t= 1.6 s
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Loaded all draft data.
# Saved training set to ../data/training_sets/HBG_Trad_train.pth
# Saved validation set to ../data/training_sets/HBG_Trad_val.pth
# Using existing cardname file, ../data/cards/HBG.csv
# Starting to train model
# Validation set pick accuracy = 18.9%
#
# Starting epoch 0
# Training loss: 5.3164
#
# Starting epoch 1
# Training loss: 4.5525
#
# Starting epoch 2
# Training loss: 4.0107
# Validation set pick accuracy = 43.5%
# Saving model weights to ../data/models/HBG_Trad.pt
#
# Starting epoch 3
# Training loss: 3.5314
#
# Starting epoch 4
# Training loss: 3.1626
# Validation set pick accuracy = 49.6%
# Saving model weights to ../data/models/HBG_Trad.pt
#
# Starting epoch 5
# Training loss: 2.867
#
# Starting epoch 6
# Training loss: 2.5803
# Validation set pick accuracy = 54.0%
# Saving model weights to ../data/models/HBG_Trad.pt
#
# Starting epoch 7
# Training loss: 2.363
#
# Starting epoch 8
# Training loss: 2.108
# Validation set pick accuracy = 57.7%
# Saving model weights to ../data/models/HBG_Trad.pt
#
# Starting epoch 9
# Training loss: 1.9084
#
# Starting epoch 10
# Training loss: 1.6841
# Validation set pick accuracy = 60.6%
# Saving model weights to ../data/models/HBG_Trad.pt
#
# Starting epoch 11
# Training loss: 1.4905
#
# Starting epoch 12
# Training loss: 1.3385
# Validation set pick accuracy = 63.6%
# Saving model weights to ../data/models/HBG_Trad.pt
#
# Starting epoch 13
# Training loss: 1.2611
#
# Starting epoch 14
# Training loss: 1.1439
# Validation set pick accuracy = 65.0%
# Saving model weights to ../data/models/HBG_Trad.pt
#
# Starting epoch 15
# Training loss: 1.077
#
# Starting epoch 16
# Training loss: 1.0305
# Validation set pick accuracy = 65.9%
# Saving model weights to ../data/models/HBG_Trad.pt
#
# Starting epoch 17
# Training loss: 0.9957
#
# Starting epoch 18
# Training loss: 0.967
# Validation set pick accuracy = 66.8%
# Saving model weights to ../data/models/HBG_Trad.pt
#
# Starting epoch 19
# Training loss: 0.9208
#
# Starting epoch 20
# Training loss: 0.9083
# Validation set pick accuracy = 66.9%
# Saving model weights to ../data/models/HBG_Trad.pt
#
# Starting epoch 21
# Training loss: 0.8931
#
# Starting epoch 22
# Training loss: 0.8836
# Validation set pick accuracy = 66.8%
#
# Starting epoch 23
# Training loss: 0.8472
#
# Starting epoch 24
# Training loss: 0.8395
# Validation set pick accuracy = 67.2%
# Saving model weights to ../data/models/HBG_Trad.pt
# Training completed.
# Starting training for SIR, Trad
# Using input file ../data/17lands/draft_data_public.SIR.TradDraft.csv.gz
# Completed initialization.
# Filtering by match wins >= 3
# Loaded 0 picks, t= 1.9 s
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Loaded all draft data.
# Saved training set to ../data/training_sets/SIR_Trad_train.pth
# Saved validation set to ../data/training_sets/SIR_Trad_val.pth
# Using existing cardname file, ../data/cards/SIR.csv
# Starting to train model
# Validation set pick accuracy = 17.5%
#
# Starting epoch 0
# Training loss: 5.3835
#
# Starting epoch 1
# Training loss: 4.2425
#
# Starting epoch 2
# Training loss: 3.525
# Validation set pick accuracy = 46.8%
# Saving model weights to ../data/models/SIR_Trad.pt
#
# Starting epoch 3
# Training loss: 3.0652
#
# Starting epoch 4
# Training loss: 2.7024
# Validation set pick accuracy = 52.8%
# Saving model weights to ../data/models/SIR_Trad.pt
#
# Starting epoch 5
# Training loss: 2.3781
#
# Starting epoch 6
# Training loss: 2.0724
# Validation set pick accuracy = 57.9%
# Saving model weights to ../data/models/SIR_Trad.pt
#
# Starting epoch 7
# Training loss: 1.7938
#
# Starting epoch 8
# Training loss: 1.5414
# Validation set pick accuracy = 60.6%
# Saving model weights to ../data/models/SIR_Trad.pt
#
# Starting epoch 9
# Training loss: 1.3518
#
# Starting epoch 10
# Training loss: 1.2119
# Validation set pick accuracy = 62.2%
# Saving model weights to ../data/models/SIR_Trad.pt
#
# Starting epoch 11
# Training loss: 1.1112
#
# Starting epoch 12
# Training loss: 1.044
# Validation set pick accuracy = 62.6%
# Saving model weights to ../data/models/SIR_Trad.pt
#
# Starting epoch 13
# Training loss: 0.9951
#
# Starting epoch 14
# Training loss: 0.9616
# Validation set pick accuracy = 63.1%
# Saving model weights to ../data/models/SIR_Trad.pt
#
# Starting epoch 15
# Training loss: 0.9311
#
# Starting epoch 16
# Training loss: 0.9078
# Validation set pick accuracy = 63.3%
# Saving model weights to ../data/models/SIR_Trad.pt
#
# Starting epoch 17
# Training loss: 0.8929
#
# Starting epoch 18
# Training loss: 0.8745
# Validation set pick accuracy = 63.2%
#
# Starting epoch 19
# Training loss: 0.8613
#
# Starting epoch 20
# Training loss: 0.8516
# Validation set pick accuracy = 63.5%
# Saving model weights to ../data/models/SIR_Trad.pt
#
# Starting epoch 21
# Training loss: 0.8403
#
# Starting epoch 22
# Training loss: 0.8283
# Validation set pick accuracy = 63.7%
# Saving model weights to ../data/models/SIR_Trad.pt
#
# Starting epoch 23
# Training loss: 0.8193
#
# Starting epoch 24
# Training loss: 0.8119
# Validation set pick accuracy = 63.6%
# Training completed.
# Starting training for WOE, Trad
# Using input file ../data/17lands/draft_data_public.WOE.TradDraft.csv.gz
# Completed initialization.
# Filtering by match wins >= 3
# Loaded 0 picks, t= 1.7 s
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Loaded 1000000 picks, t= 18.5 s
# Filtering by match wins >= 3
# Loaded all draft data.
# Saved training set to ../data/training_sets/WOE_Trad_train.pth
# Saved validation set to ../data/training_sets/WOE_Trad_val.pth
# Using existing cardname file, ../data/cards/WOE.csv
# Starting to train model
# Validation set pick accuracy = 16.3%
#
# Starting epoch 0
# Training loss: 4.8218
#
# Starting epoch 1
# Training loss: 3.2821
#
# Starting epoch 2
# Training loss: 2.3785
# Validation set pick accuracy = 60.1%
# Saving model weights to ../data/models/WOE_Trad.pt
#
# Starting epoch 3
# Training loss: 1.6275
#
# Starting epoch 4
# Training loss: 1.1912
# Validation set pick accuracy = 66.5%
# Saving model weights to ../data/models/WOE_Trad.pt
#
# Starting epoch 5
# Training loss: 1.0177
#
# Starting epoch 6
# Training loss: 0.9408
# Validation set pick accuracy = 67.7%
# Saving model weights to ../data/models/WOE_Trad.pt
#
# Starting epoch 7
# Training loss: 0.9064
#
# Starting epoch 8
# Training loss: 0.8833
# Validation set pick accuracy = 68.0%
# Saving model weights to ../data/models/WOE_Trad.pt
#
# Starting epoch 9
# Training loss: 0.8672
#
# Starting epoch 10
# Training loss: 0.8566
# Validation set pick accuracy = 67.9%
#
# Starting epoch 11
# Training loss: 0.848
#
# Starting epoch 12
# Training loss: 0.8388
# Validation set pick accuracy = 68.1%
# Saving model weights to ../data/models/WOE_Trad.pt
#
# Starting epoch 13
# Training loss: 0.8322
#
# Starting epoch 14
# Training loss: 0.8253
# Validation set pick accuracy = 68.1%
#
# Starting epoch 15
# Training loss: 0.8213
#
# Starting epoch 16
# Training loss: 0.8145
# Validation set pick accuracy = 68.0%
#
# Starting epoch 17
# Training loss: 0.8109
#
# Starting epoch 18
# Training loss: 0.8056
# Validation set pick accuracy = 68.2%
# Saving model weights to ../data/models/WOE_Trad.pt
#
# Starting epoch 19
# Training loss: 0.8015
#
# Starting epoch 20
# Training loss: 0.7981
# Validation set pick accuracy = 68.2%
# Saving model weights to ../data/models/WOE_Trad.pt
#
# Starting epoch 21
# Training loss: 0.7928
#
# Starting epoch 22
# Training loss: 0.7876
# Validation set pick accuracy = 68.2%
#
# Starting epoch 23
# Training loss: 0.7852
#
# Starting epoch 24
# Training loss: 0.7795
# Validation set pick accuracy = 68.1%
# Training completed.
# Starting training for KTK, Trad
# Using input file ../data/17lands/draft_data_public.KTK.TradDraft.csv.gz
# Completed initialization.
# Filtering by match wins >= 3
# Loaded 0 picks, t= 1.3 s
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Loaded all draft data.
# Saved training set to ../data/training_sets/KTK_Trad_train.pth
# Saved validation set to ../data/training_sets/KTK_Trad_val.pth
# Using existing cardname file, ../data/cards/KTK.csv
# Starting to train model
# Validation set pick accuracy = 16.2%
#
# Starting epoch 0
# Training loss: 5.3477
#
# Starting epoch 1
# Training loss: 4.6722
#
# Starting epoch 2
# Training loss: 4.0822
# Validation set pick accuracy = 40.7%
# Saving model weights to ../data/models/KTK_Trad.pt
#
# Starting epoch 3
# Training loss: 3.6639
#
# Starting epoch 4
# Training loss: 3.3565
# Validation set pick accuracy = 44.4%
# Saving model weights to ../data/models/KTK_Trad.pt
#
# Starting epoch 5
# Training loss: 3.1305
#
# Starting epoch 6
# Training loss: 2.9011
# Validation set pick accuracy = 51.4%
# Saving model weights to ../data/models/KTK_Trad.pt
#
# Starting epoch 7
# Training loss: 2.6822
#
# Starting epoch 8
# Training loss: 2.4803
# Validation set pick accuracy = 55.7%
# Saving model weights to ../data/models/KTK_Trad.pt
#
# Starting epoch 9
# Training loss: 2.2654
#
# Starting epoch 10
# Training loss: 2.0696
# Validation set pick accuracy = 58.6%
# Saving model weights to ../data/models/KTK_Trad.pt
#
# Starting epoch 11
# Training loss: 1.8802
#
# Starting epoch 12
# Training loss: 1.7015
# Validation set pick accuracy = 60.8%
# Saving model weights to ../data/models/KTK_Trad.pt
#
# Starting epoch 13
# Training loss: 1.5451
#
# Starting epoch 14
# Training loss: 1.4112
# Validation set pick accuracy = 63.2%
# Saving model weights to ../data/models/KTK_Trad.pt
#
# Starting epoch 15
# Training loss: 1.2954
#
# Starting epoch 16
# Training loss: 1.2036
# Validation set pick accuracy = 64.6%
# Saving model weights to ../data/models/KTK_Trad.pt
#
# Starting epoch 17
# Training loss: 1.1279
#
# Starting epoch 18
# Training loss: 1.0639
# Validation set pick accuracy = 65.2%
# Saving model weights to ../data/models/KTK_Trad.pt
#
# Starting epoch 19
# Training loss: 1.0124
#
# Starting epoch 20
# Training loss: 0.9696
# Validation set pick accuracy = 65.8%
# Saving model weights to ../data/models/KTK_Trad.pt
#
# Starting epoch 21
# Training loss: 0.9378
#
# Starting epoch 22
# Training loss: 0.9091
# Validation set pick accuracy = 65.9%
# Saving model weights to ../data/models/KTK_Trad.pt
#
# Starting epoch 23
# Training loss: 0.8846
#
# Starting epoch 24
# Training loss: 0.8656
# Validation set pick accuracy = 66.3%
# Saving model weights to ../data/models/KTK_Trad.pt
# Training completed.
# Starting training for FDN, Premier
# Using input file ../data/17lands/draft_data_public.FDN.PremierDraft.csv.gz
# Completed initialization.
# Filtering by match wins >= 7
# Loaded 0 picks, t= 1.5 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 1000000 picks, t= 16.7 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 2000000 picks, t= 31.4 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 3000000 picks, t= 46.2 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded all draft data.
# Saved training set to ../data/training_sets/FDN_Premier_train.pth
# Saved validation set to ../data/training_sets/FDN_Premier_val.pth
# Using existing cardname file, ../data/cards/FDN.csv
# Starting to train model
# Validation set pick accuracy = 18.5%
#
# Starting epoch 0
# Training loss: 4.1796
#
# Starting epoch 1
# Training loss: 2.5024
#
# Starting epoch 2
# Training loss: 1.6072
# Validation set pick accuracy = 66.7%
# Saving model weights to ../data/models/FDN_Premier.pt
#
# Starting epoch 3
# Training loss: 1.1199
#
# Starting epoch 4
# Training loss: 0.9597
# Validation set pick accuracy = 68.6%
# Saving model weights to ../data/models/FDN_Premier.pt
#
# Starting epoch 5
# Training loss: 0.9009
#
# Starting epoch 6
# Training loss: 0.8709
# Validation set pick accuracy = 69.0%
# Saving model weights to ../data/models/FDN_Premier.pt
#
# Starting epoch 7
# Training loss: 0.854
#
# Starting epoch 8
# Training loss: 0.8428
# Validation set pick accuracy = 69.2%
# Saving model weights to ../data/models/FDN_Premier.pt
#
# Starting epoch 9
# Training loss: 0.8345
#
# Starting epoch 10
# Training loss: 0.8263
# Validation set pick accuracy = 69.5%
# Saving model weights to ../data/models/FDN_Premier.pt
#
# Starting epoch 11
# Training loss: 0.8219
#
# Starting epoch 12
# Training loss: 0.8148
# Validation set pick accuracy = 69.3%
#
# Starting epoch 13
# Training loss: 0.8115
#
# Starting epoch 14
# Training loss: 0.808
# Validation set pick accuracy = 69.3%
#
# Starting epoch 15
# Training loss: 0.8046
#
# Starting epoch 16
# Training loss: 0.8002
# Validation set pick accuracy = 69.6%
# Saving model weights to ../data/models/FDN_Premier.pt
#
# Starting epoch 17
# Training loss: 0.7958
#
# Starting epoch 18
# Training loss: 0.7925
# Validation set pick accuracy = 69.4%
#
# Starting epoch 19
# Training loss: 0.7888
#
# Starting epoch 20
# Training loss: 0.7864
# Validation set pick accuracy = 69.5%
#
# Starting epoch 21
# Training loss: 0.7839
#
# Starting epoch 22
# Training loss: 0.7789
# Validation set pick accuracy = 69.6%
# Saving model weights to ../data/models/FDN_Premier.pt
#
# Starting epoch 23
# Training loss: 0.7767
#
# Starting epoch 24
# Training loss: 0.7737
# Validation set pick accuracy = 69.6%
# Training completed.
# Starting training for WOE, Premier
# Using input file ../data/17lands/draft_data_public.WOE.PremierDraft.csv.gz
# Completed initialization.
# Filtering by match wins >= 7
# Loaded 0 picks, t= 1.6 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 1000000 picks, t= 18.2 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 2000000 picks, t= 34.5 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 3000000 picks, t= 50.7 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 4000000 picks, t= 66.8 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 5000000 picks, t= 82.9 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 6000000 picks, t= 99.3 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 7000000 picks, t= 114.5 s
# Loaded all draft data.
# Saved training set to ../data/training_sets/WOE_Premier_train.pth
# Saved validation set to ../data/training_sets/WOE_Premier_val.pth
# Using existing cardname file, ../data/cards/WOE.csv
# Starting to train model
# Validation set pick accuracy = 18.2%
#
# Starting epoch 0
# Training loss: 3.6079
#
# Starting epoch 1
# Training loss: 1.4252
#
# Starting epoch 2
# Training loss: 0.976
# Validation set pick accuracy = 67.8%
# Saving model weights to ../data/models/WOE_Premier.pt
#
# Starting epoch 3
# Training loss: 0.9083
#
# Starting epoch 4
# Training loss: 0.8868
# Validation set pick accuracy = 68.2%
# Saving model weights to ../data/models/WOE_Premier.pt
#
# Starting epoch 5
# Training loss: 0.8735
#
# Starting epoch 6
# Training loss: 0.8659
# Validation set pick accuracy = 68.4%
# Saving model weights to ../data/models/WOE_Premier.pt
#
# Starting epoch 7
# Training loss: 0.8588
#
# Starting epoch 8
# Training loss: 0.8539
# Validation set pick accuracy = 68.4%
# Saving model weights to ../data/models/WOE_Premier.pt
#
# Starting epoch 9
# Training loss: 0.8498
#
# Starting epoch 10
# Training loss: 0.8462
# Validation set pick accuracy = 68.6%
# Saving model weights to ../data/models/WOE_Premier.pt
#
# Starting epoch 11
# Training loss: 0.842
#
# Starting epoch 12
# Training loss: 0.8409
# Validation set pick accuracy = 68.7%
# Saving model weights to ../data/models/WOE_Premier.pt
#
# Starting epoch 13
# Training loss: 0.8367
#
# Starting epoch 14
# Training loss: 0.8341
# Validation set pick accuracy = 68.7%
# Saving model weights to ../data/models/WOE_Premier.pt
#
# Starting epoch 15
# Training loss: 0.8317
#
# Starting epoch 16
# Training loss: 0.8292
# Validation set pick accuracy = 68.7%
# Saving model weights to ../data/models/WOE_Premier.pt
#
# Starting epoch 17
# Training loss: 0.8281
#
# Starting epoch 18
# Training loss: 0.8252
# Validation set pick accuracy = 68.7%
#
# Starting epoch 19
# Training loss: 0.8234
#
# Starting epoch 20
# Training loss: 0.8223
# Validation set pick accuracy = 68.5%
#
# Starting epoch 21
# Training loss: 0.8197
#
# Starting epoch 22
# Training loss: 0.8185
# Validation set pick accuracy = 68.7%
#
# Starting epoch 23
# Training loss: 0.816
#
# Starting epoch 24
# Training loss: 0.8154
# Validation set pick accuracy = 68.6%
# Training completed.
# Starting training for STX, Premier
# Using input file ../data/17lands/draft_data_public.STX.PremierDraft.csv.gz
# Completed initialization.
# Filtering by match wins >= 7
# Loaded 0 picks, t= 1.9 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 1000000 picks, t= 20.6 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 2000000 picks, t= 39.0 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 3000000 picks, t= 57.0 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded all draft data.
# Saved training set to ../data/training_sets/STX_Premier_train.pth
# Saved validation set to ../data/training_sets/STX_Premier_val.pth
# Using existing cardname file, ../data/cards/STX.csv
# Starting to train model
# Validation set pick accuracy = 18.8%
#
# Starting epoch 0
# Training loss: 3.8291
#
# Starting epoch 1
# Training loss: 2.2913
#
# Starting epoch 2
# Training loss: 1.4073
# Validation set pick accuracy = 64.9%
# Saving model weights to ../data/models/STX_Premier.pt
#
# Starting epoch 3
# Training loss: 1.0706
#
# Starting epoch 4
# Training loss: 0.9669
# Validation set pick accuracy = 66.3%
# Saving model weights to ../data/models/STX_Premier.pt
#
# Starting epoch 5
# Training loss: 0.9264
#
# Starting epoch 6
# Training loss: 0.9053
# Validation set pick accuracy = 66.8%
# Saving model weights to ../data/models/STX_Premier.pt
#
# Starting epoch 7
# Training loss: 0.8899
#
# Starting epoch 8
# Training loss: 0.8803
# Validation set pick accuracy = 67.0%
# Saving model weights to ../data/models/STX_Premier.pt
#
# Starting epoch 9
# Training loss: 0.8716
#
# Starting epoch 10
# Training loss: 0.8647
# Validation set pick accuracy = 67.3%
# Saving model weights to ../data/models/STX_Premier.pt
#
# Starting epoch 11
# Training loss: 0.859
#
# Starting epoch 12
# Training loss: 0.8536
# Validation set pick accuracy = 67.4%
# Saving model weights to ../data/models/STX_Premier.pt
#
# Starting epoch 13
# Training loss: 0.8498
#
# Starting epoch 14
# Training loss: 0.8449
# Validation set pick accuracy = 67.3%
#
# Starting epoch 15
# Training loss: 0.8416
#
# Starting epoch 16
# Training loss: 0.8385
# Validation set pick accuracy = 67.5%
# Saving model weights to ../data/models/STX_Premier.pt
#
# Starting epoch 17
# Training loss: 0.835
#
# Starting epoch 18
# Training loss: 0.8316
# Validation set pick accuracy = 67.5%
# Saving model weights to ../data/models/STX_Premier.pt
#
# Starting epoch 19
# Training loss: 0.829
#
# Starting epoch 20
# Training loss: 0.8265
# Validation set pick accuracy = 67.5%
#
# Starting epoch 21
# Training loss: 0.8222
#
# Starting epoch 22
# Training loss: 0.8188
# Validation set pick accuracy = 67.3%
#
# Starting epoch 23
# Training loss: 0.8164
#
# Starting epoch 24
# Training loss: 0.8151
# Validation set pick accuracy = 67.3%
# Training completed.
# Starting training for MH3, Trad
# Using input file ../data/17lands/draft_data_public.MH3.TradDraft.csv.gz
# Completed initialization.
# Filtering by match wins >= 3
# Loaded 0 picks, t= 1.9 s
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Loaded all draft data.
# Saved training set to ../data/training_sets/MH3_Trad_train.pth
# Saved validation set to ../data/training_sets/MH3_Trad_val.pth
# Using existing cardname file, ../data/cards/MH3.csv
# Starting to train model
# Validation set pick accuracy = 17.9%
#
# Starting epoch 0
# Training loss: 5.061
#
# Starting epoch 1
# Training loss: 3.7517
#
# Starting epoch 2
# Training loss: 3.0767
# Validation set pick accuracy = 55.2%
# Saving model weights to ../data/models/MH3_Trad.pt
#
# Starting epoch 3
# Training loss: 2.5519
#
# Starting epoch 4
# Training loss: 2.0983
# Validation set pick accuracy = 62.1%
# Saving model weights to ../data/models/MH3_Trad.pt
#
# Starting epoch 5
# Training loss: 1.677
#
# Starting epoch 6
# Training loss: 1.3578
# Validation set pick accuracy = 65.9%
# Saving model weights to ../data/models/MH3_Trad.pt
#
# Starting epoch 7
# Training loss: 1.1534
#
# Starting epoch 8
# Training loss: 1.0366
# Validation set pick accuracy = 67.2%
# Saving model weights to ../data/models/MH3_Trad.pt
#
# Starting epoch 9
# Training loss: 0.9731
#
# Starting epoch 10
# Training loss: 0.9294
# Validation set pick accuracy = 68.0%
# Saving model weights to ../data/models/MH3_Trad.pt
#
# Starting epoch 11
# Training loss: 0.9038
#
# Starting epoch 12
# Training loss: 0.8827
# Validation set pick accuracy = 68.4%
# Saving model weights to ../data/models/MH3_Trad.pt
#
# Starting epoch 13
# Training loss: 0.8691
#
# Starting epoch 14
# Training loss: 0.8569
# Validation set pick accuracy = 68.4%
# Saving model weights to ../data/models/MH3_Trad.pt
#
# Starting epoch 15
# Training loss: 0.8458
#
# Starting epoch 16
# Training loss: 0.8332
# Validation set pick accuracy = 68.6%
# Saving model weights to ../data/models/MH3_Trad.pt
#
# Starting epoch 17
# Training loss: 0.8282
#
# Starting epoch 18
# Training loss: 0.8217
# Validation set pick accuracy = 68.5%
#
# Starting epoch 19
# Training loss: 0.8104
#
# Starting epoch 20
# Training loss: 0.8087
# Validation set pick accuracy = 68.6%
#
# Starting epoch 21
# Training loss: 0.8023
#
# Starting epoch 22
# Training loss: 0.7964
# Validation set pick accuracy = 68.4%
#
# Starting epoch 23
# Training loss: 0.7909
#
# Starting epoch 24
# Training loss: 0.7832
# Validation set pick accuracy = 68.4%
# Training completed.
# Starting training for BLB, Trad
# Using input file ../data/17lands/draft_data_public.BLB.TradDraft.csv.gz
# Completed initialization.
# Filtering by match wins >= 3
# Loaded 0 picks, t= 1.4 s
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Loaded all draft data.
# Saved training set to ../data/training_sets/BLB_Trad_train.pth
# Saved validation set to ../data/training_sets/BLB_Trad_val.pth
# Using existing cardname file, ../data/cards/BLB.csv
# Starting to train model
# Validation set pick accuracy = 19.0%
#
# Starting epoch 0
# Training loss: 4.8188
#
# Starting epoch 1
# Training loss: 3.4438
#
# Starting epoch 2
# Training loss: 2.6907
# Validation set pick accuracy = 57.5%
# Saving model weights to ../data/models/BLB_Trad.pt
#
# Starting epoch 3
# Training loss: 2.1256
#
# Starting epoch 4
# Training loss: 1.6445
# Validation set pick accuracy = 66.0%
# Saving model weights to ../data/models/BLB_Trad.pt
#
# Starting epoch 5
# Training loss: 1.2835
#
# Starting epoch 6
# Training loss: 1.0754
# Validation set pick accuracy = 68.6%
# Saving model weights to ../data/models/BLB_Trad.pt
#
# Starting epoch 7
# Training loss: 0.9601
#
# Starting epoch 8
# Training loss: 0.8961
# Validation set pick accuracy = 69.5%
# Saving model weights to ../data/models/BLB_Trad.pt
#
# Starting epoch 9
# Training loss: 0.8598
#
# Starting epoch 10
# Training loss: 0.8313
# Validation set pick accuracy = 69.8%
# Saving model weights to ../data/models/BLB_Trad.pt
#
# Starting epoch 11
# Training loss: 0.8139
#
# Starting epoch 12
# Training loss: 0.7999
# Validation set pick accuracy = 70.1%
# Saving model weights to ../data/models/BLB_Trad.pt
#
# Starting epoch 13
# Training loss: 0.7874
#
# Starting epoch 14
# Training loss: 0.779
# Validation set pick accuracy = 70.0%
#
# Starting epoch 15
# Training loss: 0.7722
#
# Starting epoch 16
# Training loss: 0.7655
# Validation set pick accuracy = 70.2%
# Saving model weights to ../data/models/BLB_Trad.pt
#
# Starting epoch 17
# Training loss: 0.7585
#
# Starting epoch 18
# Training loss: 0.7533
# Validation set pick accuracy = 70.4%
# Saving model weights to ../data/models/BLB_Trad.pt
#
# Starting epoch 19
# Training loss: 0.7458
#
# Starting epoch 20
# Training loss: 0.7431
# Validation set pick accuracy = 70.4%
# Saving model weights to ../data/models/BLB_Trad.pt
#
# Starting epoch 21
# Training loss: 0.736
#
# Starting epoch 22
# Training loss: 0.734
# Validation set pick accuracy = 70.3%
#
# Starting epoch 23
# Training loss: 0.7285
#
# Starting epoch 24
# Training loss: 0.7226
# Validation set pick accuracy = 70.4%
# Saving model weights to ../data/models/BLB_Trad.pt
# Training completed.
# Starting training for AFR, Premier
# Using input file ../data/17lands/draft_data_public.AFR.PremierDraft.csv.gz
# Completed initialization.
# Filtering by match wins >= 7
# Loaded 0 picks, t= 1.5 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 1000000 picks, t= 15.6 s
# Loaded all draft data.
# Saved training set to ../data/training_sets/AFR_Premier_train.pth
# Saved validation set to ../data/training_sets/AFR_Premier_val.pth
# Using existing cardname file, ../data/cards/AFR.csv
# Starting to train model
# Validation set pick accuracy = 17.6%
#
# Starting epoch 0
# Training loss: 4.9227
#
# Starting epoch 1
# Training loss: 3.7077
#
# Starting epoch 2
# Training loss: 3.0098
# Validation set pick accuracy = 52.1%
# Saving model weights to ../data/models/AFR_Premier.pt
#
# Starting epoch 3
# Training loss: 2.5694
#
# Starting epoch 4
# Training loss: 2.2038
# Validation set pick accuracy = 58.7%
# Saving model weights to ../data/models/AFR_Premier.pt
#
# Starting epoch 5
# Training loss: 1.8564
#
# Starting epoch 6
# Training loss: 1.5398
# Validation set pick accuracy = 62.6%
# Saving model weights to ../data/models/AFR_Premier.pt
#
# Starting epoch 7
# Training loss: 1.3203
#
# Starting epoch 8
# Training loss: 1.1695
# Validation set pick accuracy = 64.5%
# Saving model weights to ../data/models/AFR_Premier.pt
#
# Starting epoch 9
# Training loss: 1.0697
#
# Starting epoch 10
# Training loss: 1.0118
# Validation set pick accuracy = 65.1%
# Saving model weights to ../data/models/AFR_Premier.pt
#
# Starting epoch 11
# Training loss: 0.9772
#
# Starting epoch 12
# Training loss: 0.9538
# Validation set pick accuracy = 65.4%
# Saving model weights to ../data/models/AFR_Premier.pt
#
# Starting epoch 13
# Training loss: 0.9304
#
# Starting epoch 14
# Training loss: 0.9137
# Validation set pick accuracy = 65.5%
# Saving model weights to ../data/models/AFR_Premier.pt
#
# Starting epoch 15
# Training loss: 0.9028
#
# Starting epoch 16
# Training loss: 0.8956
# Validation set pick accuracy = 65.8%
# Saving model weights to ../data/models/AFR_Premier.pt
#
# Starting epoch 17
# Training loss: 0.8842
#
# Starting epoch 18
# Training loss: 0.8734
# Validation set pick accuracy = 65.8%
# Saving model weights to ../data/models/AFR_Premier.pt
#
# Starting epoch 19
# Training loss: 0.8713
#
# Starting epoch 20
# Training loss: 0.86
# Validation set pick accuracy = 65.8%
# Saving model weights to ../data/models/AFR_Premier.pt
#
# Starting epoch 21
# Training loss: 0.8582
#
# Starting epoch 22
# Training loss: 0.8511
# Validation set pick accuracy = 65.9%
# Saving model weights to ../data/models/AFR_Premier.pt
#
# Starting epoch 23
# Training loss: 0.8479
#
# Starting epoch 24
# Training loss: 0.844
# Validation set pick accuracy = 65.8%
# Training completed.
# Starting training for LTR, Premier
# Using input file ../data/17lands/draft_data_public.LTR.PremierDraft.csv.gz
# Completed initialization.
# Filtering by match wins >= 7
# Loaded 0 picks, t= 1.4 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 1000000 picks, t= 15.9 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 2000000 picks, t= 30.1 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 3000000 picks, t= 44.4 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 4000000 picks, t= 58.5 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 5000000 picks, t= 72.5 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 6000000 picks, t= 86.6 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded all draft data.
# Saved training set to ../data/training_sets/LTR_Premier_train.pth
# Saved validation set to ../data/training_sets/LTR_Premier_val.pth
# Using existing cardname file, ../data/cards/LTR.csv
# Starting to train model
# Validation set pick accuracy = 18.8%
#
# Starting epoch 0
# Training loss: 3.5009
#
# Starting epoch 1
# Training loss: 1.4756
#
# Starting epoch 2
# Training loss: 0.9603
# Validation set pick accuracy = 69.4%
# Saving model weights to ../data/models/LTR_Premier.pt
#
# ...
# Saving model weights to ../data/models/FDN_Trad.pt
#
# Starting epoch 5
# Training loss: 2.5827
#
# Starting epoch 6
# Training loss: 2.3244
# Validation set pick accuracy = 58.2%
# Saving model weights to ../data/models/FDN_Trad.pt
#
# Starting epoch 7
# Training loss: 2.0847
#
# Starting epoch 8
# Training loss: 1.8482
# Validation set pick accuracy = 62.1%
# Saving model weights to ../data/models/FDN_Trad.pt
#
# Starting epoch 9
# Training loss: 1.6288
#
# Starting epoch 10
# Training loss: 1.4307
# Validation set pick accuracy = 64.6%
# Saving model weights to ../data/models/FDN_Trad.pt
#
# Starting epoch 11
# Training loss: 1.2842
#
# Starting epoch 12
# Training loss: 1.1554
# Validation set pick accuracy = 66.1%
# Saving model weights to ../data/models/FDN_Trad.pt
#
# Starting epoch 13
# Training loss: 1.064
#
# Starting epoch 14
# Training loss: 1.0003
# Validation set pick accuracy = 66.9%
# Saving model weights to ../data/models/FDN_Trad.pt
#
# Starting epoch 15
# Training loss: 0.9457
#
# Starting epoch 16
# Training loss: 0.9083
# Validation set pick accuracy = 67.1%
# Saving model weights to ../data/models/FDN_Trad.pt
#
# Starting epoch 17
# Training loss: 0.8802
#
# Starting epoch 18
# Training loss: 0.8558
# Validation set pick accuracy = 67.2%
# Saving model weights to ../data/models/FDN_Trad.pt
#
# Starting epoch 19
# Training loss: 0.8333
#
# Starting epoch 20
# Training loss: 0.8196
# Validation set pick accuracy = 67.5%
# Saving model weights to ../data/models/FDN_Trad.pt
#
# Starting epoch 21
# Training loss: 0.8055
#
# Starting epoch 22
# Training loss: 0.7926
# Validation set pick accuracy = 67.7%
# Saving model weights to ../data/models/FDN_Trad.pt
#
# Starting epoch 23
# Training loss: 0.777
#
# Starting epoch 24
# Training loss: 0.7696
# Validation set pick accuracy = 67.7%
# Training completed.
# Starting training for MKM, Premier
# Using input file ../data/17lands/draft_data_public.MKM.PremierDraft.csv.gz
# Completed initialization.
# Filtering by match wins >= 7
# Loaded 0 picks, t= 1.7 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 1000000 picks, t= 18.4 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 2000000 picks, t= 35.0 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 3000000 picks, t= 51.2 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 4000000 picks, t= 67.1 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 5000000 picks, t= 83.4 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 6000000 picks, t= 99.4 s
# Filtering by match wins >= 7
# Loaded all draft data.
# Saved training set to ../data/training_sets/MKM_Premier_train.pth
# Saved validation set to ../data/training_sets/MKM_Premier_val.pth
# Using existing cardname file, ../data/cards/MKM.csv
# Starting to train model
# Validation set pick accuracy = 18.9%
#
# Starting epoch 0
# Training loss: 3.8791
#
# Starting epoch 1
# Training loss: 1.7459
#
# Starting epoch 2
# Training loss: 1.0293
# Validation set pick accuracy = 68.3%
# Saving model weights to ../data/models/MKM_Premier.pt
#
# Starting epoch 3
# Training loss: 0.917
#
# Starting epoch 4
# Training loss: 0.8842
# Validation set pick accuracy = 69.1%
# Saving model weights to ../data/models/MKM_Premier.pt
#
# Starting epoch 5
# Training loss: 0.8669
#
# Starting epoch 6
# Training loss: 0.857
# Validation set pick accuracy = 69.4%
# Saving model weights to ../data/models/MKM_Premier.pt
#
# Starting epoch 7
# Training loss: 0.8495
#
# Starting epoch 8
# Training loss: 0.8438
# Validation set pick accuracy = 69.5%
# Saving model weights to ../data/models/MKM_Premier.pt
#
# Starting epoch 9
# Training loss: 0.8384
#
# Starting epoch 10
# Training loss: 0.8343
# Validation set pick accuracy = 69.5%
# Saving model weights to ../data/models/MKM_Premier.pt
#
# Starting epoch 11
# Training loss: 0.8308
#
# Starting epoch 12
# Training loss: 0.8269
# Validation set pick accuracy = 69.6%
# Saving model weights to ../data/models/MKM_Premier.pt
#
# Starting epoch 13
# Training loss: 0.8246
#
# Starting epoch 14
# Training loss: 0.822
# Validation set pick accuracy = 69.6%
#
# Starting epoch 15
# Training loss: 0.8196
#
# Starting epoch 16
# Training loss: 0.8176
# Validation set pick accuracy = 69.6%
# Saving model weights to ../data/models/MKM_Premier.pt
#
# Starting epoch 17
# Training loss: 0.8135
#
# Starting epoch 18
# Training loss: 0.812
# Validation set pick accuracy = 69.6%
# Saving model weights to ../data/models/MKM_Premier.pt
#
# Starting epoch 19
# Training loss: 0.8103
#
# Starting epoch 20
# Training loss: 0.8075
# Validation set pick accuracy = 69.7%
# Saving model weights to ../data/models/MKM_Premier.pt
#
# Starting epoch 21
# Training loss: 0.8065
#
# Starting epoch 22
# Training loss: 0.8042
# Validation set pick accuracy = 69.7%
# Saving model weights to ../data/models/MKM_Premier.pt
#
# Starting epoch 23
# Training loss: 0.8032
#
# Starting epoch 24
# Training loss: 0.7994
# Validation set pick accuracy = 69.7%
# Training completed.
# Starting training for LCI, Premier
# Using input file ../data/17lands/draft_data_public.LCI.PremierDraft.csv.gz
# Completed initialization.
# Filtering by match wins >= 7
# Loaded 0 picks, t= 1.6 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 1000000 picks, t= 17.2 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 2000000 picks, t= 32.5 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 3000000 picks, t= 47.8 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 4000000 picks, t= 63.0 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 5000000 picks, t= 78.1 s
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Filtering by match wins >= 7
# Loaded 6000000 picks, t= 93.3 s
# Filtering by match wins >= 7
# Loaded all draft data.
# Saved training set to ../data/training_sets/LCI_Premier_train.pth
# Saved validation set to ../data/training_sets/LCI_Premier_val.pth
# Using existing cardname file, ../data/cards/LCI.csv
# Starting to train model
# Validation set pick accuracy = 18.2%
#
# Starting epoch 0
# Training loss: 3.646
#
# Starting epoch 1
# Training loss: 1.6978
#
# Starting epoch 2
# Training loss: 1.0567
# Validation set pick accuracy = 67.6%
# Saving model weights to ../data/models/LCI_Premier.pt
#
# Starting epoch 3
# Training loss: 0.9388
#
# Starting epoch 4
# Training loss: 0.9021
# Validation set pick accuracy = 68.4%
# Saving model weights to ../data/models/LCI_Premier.pt
#
# Starting epoch 5
# Training loss: 0.8855
#
# Starting epoch 6
# Training loss: 0.8759
# Validation set pick accuracy = 68.3%
#
# Starting epoch 7
# Training loss: 0.8674
#
# Starting epoch 8
# Training loss: 0.8624
# Validation set pick accuracy = 68.4%
# Saving model weights to ../data/models/LCI_Premier.pt
#
# Starting epoch 9
# Training loss: 0.8576
#
# Starting epoch 10
# Training loss: 0.8533
# Validation set pick accuracy = 68.7%
# Saving model weights to ../data/models/LCI_Premier.pt
#
# Starting epoch 11
# Training loss: 0.8486
#
# Starting epoch 12
# Training loss: 0.8451
# Validation set pick accuracy = 68.8%
# Saving model weights to ../data/models/LCI_Premier.pt
#
# Starting epoch 13
# Training loss: 0.843
#
# Starting epoch 14
# Training loss: 0.8395
# Validation set pick accuracy = 68.8%
# Saving model weights to ../data/models/LCI_Premier.pt
#
# Starting epoch 15
# Training loss: 0.8367
#
# Starting epoch 16
# Training loss: 0.8335
# Validation set pick accuracy = 68.9%
# Saving model weights to ../data/models/LCI_Premier.pt
#
# Starting epoch 17
# Training loss: 0.8324
#
# Starting epoch 18
# Training loss: 0.8298
# Validation set pick accuracy = 68.8%
#
# Starting epoch 19
# Training loss: 0.8282
#
# Starting epoch 20
# Training loss: 0.8261
# Validation set pick accuracy = 68.9%
# Saving model weights to ../data/models/LCI_Premier.pt
#
# Starting epoch 21
# Training loss: 0.8233
#
# Starting epoch 22
# Training loss: 0.8227
# Validation set pick accuracy = 68.8%
#
# Starting epoch 23
# Training loss: 0.8203
#
# Starting epoch 24
# Training loss: 0.818
# Validation set pick accuracy = 68.7%
# Training completed.
# Starting training for DMU, Trad
# Using input file ../data/17lands/draft_data_public.DMU.TradDraft.csv.gz
# Completed initialization.
# Filtering by match wins >= 3
# Loaded 0 picks, t= 1.8 s
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Loaded 1000000 picks, t= 18.7 s
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Loaded all draft data.
# Saved training set to ../data/training_sets/DMU_Trad_train.pth
# Saved validation set to ../data/training_sets/DMU_Trad_val.pth
# Using existing cardname file, ../data/cards/DMU.csv
# Starting to train model
# Validation set pick accuracy = 19.3%
#
# Starting epoch 0
# Training loss: 4.5251
#
# Starting epoch 1
# Training loss: 3.0703
#
# Starting epoch 2
# Training loss: 2.1786
# Validation set pick accuracy = 60.5%
# Saving model weights to ../data/models/DMU_Trad.pt
#
# Starting epoch 3
# Training loss: 1.477
#
# Starting epoch 4
# Training loss: 1.1424
# Validation set pick accuracy = 65.9%
# Saving model weights to ../data/models/DMU_Trad.pt
#
# Starting epoch 5
# Training loss: 1.0145
#
# Starting epoch 6
# Training loss: 0.9621
# Validation set pick accuracy = 66.6%
# Saving model weights to ../data/models/DMU_Trad.pt
#
# Starting epoch 7
# Training loss: 0.932
#
# Starting epoch 8
# Training loss: 0.9154
# Validation set pick accuracy = 67.0%
# Saving model weights to ../data/models/DMU_Trad.pt
#
# Starting epoch 9
# Training loss: 0.901
#
# Starting epoch 10
# Training loss: 0.8903
# Validation set pick accuracy = 67.1%
# Saving model weights to ../data/models/DMU_Trad.pt
#
# Starting epoch 11
# Training loss: 0.8823
#
# Starting epoch 12
# Training loss: 0.8769
# Validation set pick accuracy = 67.3%
# Saving model weights to ../data/models/DMU_Trad.pt
#
# Starting epoch 13
# Training loss: 0.8719
#
# Starting epoch 14
# Training loss: 0.865
# Validation set pick accuracy = 67.4%
# Saving model weights to ../data/models/DMU_Trad.pt
#
# Starting epoch 15
# Training loss: 0.8594
#
# Starting epoch 16
# Training loss: 0.8544
# Validation set pick accuracy = 67.4%
# Saving model weights to ../data/models/DMU_Trad.pt
#
# Starting epoch 17
# Training loss: 0.8507
#
# Starting epoch 18
# Training loss: 0.8468
# Validation set pick accuracy = 67.3%
#
# Starting epoch 19
# Training loss: 0.8423
#
# Starting epoch 20
# Training loss: 0.8382
# Validation set pick accuracy = 67.4%
#
# Starting epoch 21
# Training loss: 0.835
#
# Starting epoch 22
# Training loss: 0.8311
# Validation set pick accuracy = 67.3%
#
# Starting epoch 23
# Training loss: 0.8261
#
# Starting epoch 24
# Training loss: 0.8228
# Validation set pick accuracy = 67.2%
# Training completed.
# Starting training for MOM, Trad
# Using input file ../data/17lands/draft_data_public.MOM.TradDraft.csv.gz
# Completed initialization.
# Filtering by match wins >= 3
# Loaded 0 picks, t= 1.8 s
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Loaded 1000000 picks, t= 19.9 s
# Filtering by match wins >= 3
# Filtering by match wins >= 3
# Loaded all draft data.
# Saved training set to ../data/training_sets/MOM_Trad_train.pth
# Saved validation set to ../data/training_sets/MOM_Trad_val.pth
# Using existing cardname file, ../data/cards/MOM.csv
# Starting to train model
# Validation set pick accuracy = 17.6%
#
# Starting epoch 0
# Training loss: 5.0499
#
# Starting epoch 1
# Training loss: 3.5857
#
# Starting epoch 2
# Training loss: 2.7464
# Validation set pick accuracy = 55.4%
# Saving model weights to ../data/models/MOM_Trad.pt
#
# Starting epoch 3
# Training loss: 2.1131
#
# Starting epoch 4
# Training loss: 1.5921
# Validation set pick accuracy = 63.7%
# Saving model weights to ../data/models/MOM_Trad.pt
#
# Starting epoch 5
# Training loss: 1.2576
#
# Starting epoch 6
# Training loss: 1.0864
# Validation set pick accuracy = 65.5%
# Saving model weights to ../data/models/MOM_Trad.pt
#
# Starting epoch 7
# Training loss: 1.0035
#
# Starting epoch 8
# Training loss: 0.956
# Validation set pick accuracy = 66.2%
# Saving model weights to ../data/models/MOM_Trad.pt
#
# Starting epoch 9
# Training loss: 0.9273
#
# Starting epoch 10
# Training loss: 0.9038
# Validation set pick accuracy = 66.6%
# Saving model weights to ../data/models/MOM_Trad.pt
#
# Starting epoch 11
# Training loss: 0.886
#
# Starting epoch 12
# Training loss: 0.8752
# Validation set pick accuracy = 66.9%
# Saving model weights to ../data/models/MOM_Trad.pt
#
# Starting epoch 13
# Training loss: 0.8636
#
# Starting epoch 14
# Training loss: 0.8529
# Validation set pick accuracy = 66.8%
#
# Starting epoch 15
# Training loss: 0.8448
#
# Starting epoch 16
# Training loss: 0.8388
# Validation set pick accuracy = 67.0%
# Saving model weights to ../data/models/MOM_Trad.pt
#
# Starting epoch 17
# Training loss: 0.8306
#
# Starting epoch 18
# Training loss: 0.826
# Validation set pick accuracy = 67.2%
# Saving model weights to ../data/models/MOM_Trad.pt
#
# Starting epoch 19
# Training loss: 0.8204
#
# Starting epoch 20
# Training loss: 0.8133
# Validation set pick accuracy = 67.3%
# Saving model weights to ../data/models/MOM_Trad.pt
#
# Starting epoch 21
# Training loss: 0.8069
#
# Starting epoch 22
# Training loss: 0.8028
# Validation set pick accuracy = 67.4%
# Saving model weights to ../data/models/MOM_Trad.pt
#
# Starting epoch 23
# Training loss: 0.7974
#
# Starting epoch 24
# Training loss: 0.7909
# Validation set pick accuracy = 67.1%
# Training completed.

# %%
model_path = "../data/models"

draft_models = [dm.split(".")[0].split("_") for dm in os.listdir(model_path) if ".pt" in dm]
sets = set([dm[0] for dm in draft_models])

df = pd.DataFrame(draft_models, columns=["set", "draft_mode"])
x = df.groupby(["set", "draft_mode"]).size().unstack(fill_value=0)
x
# Out:
# draft_mode  Premier  Trad
# set
# AFR               1     0
# BLB               1     1
# BRO               1     1
# DMU               1     1
# DSK               1     1
# FDN               1     1
# HBG               1     1
# KTK               1     1
# LCI               1     1
# LTR               1     1
# MH3               1     1
# MID               1     0
# MKM               1     1
# MOM               1     1
# NEO               1     1
# ONE               1     1
# OTJ               1     1
# SIR               1     1
# SNC               0     1
# STX               1     1
# VOW               1     0
# WOE               1     1

# %%
x.columns
# Out:
# Index(['set', 'Premier', 'Trad'], dtype='object', name='draft_mode')
